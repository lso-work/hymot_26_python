# %% [markdown]
# # Python 프로그래밍 10주차: 클래스 II

# %% [markdown]
# ## p.11 계산기 더하기 기능: 전역변수

# %%
result = 0

def adder(num):
    global result
    result += num
    return result

print(adder(3))
print(adder(4))
# Out:
# 3
# 7

# %% [markdown]
# ## p.12 만약 계산기가 두 개 필요하다면?

# %%
result1 = 0
result2 = 0

def adder1(num):
    global result1
    result1 += num
    return result1

def adder2(num):
    global result2
    result2 += num
    return result2

print(adder1(3))
print(adder1(4))
print(adder2(3))
print(adder2(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# ## p.13 계산기가 여러 개가 필요하다면?: 클래스 사용

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def adder(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.adder(3))
print(cal1.adder(4))
print(cal2.adder(3))
print(cal2.adder(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# ## p.15 클래스 변수

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

an = Service()
print(an.secret)
# Out:
# 지구는 4006년에 멸망한다.

# %% [markdown]
# ## p.16 클래스 변수 공유

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

an = Service()

print(Service.secret)

Service.secret = "지구가 4006년에 멸망한다는 사실은 뻥이다."

print(an.secret)
# Out:
# 지구는 4006년에 멸망한다.
# 지구가 4006년에 멸망한다는 사실은 뻥이다.

# %% [markdown]
# ## p.17 클래스 내부의 함수: 메서드

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def sum(self, a, b):
        result = a + b
        print("%s + %s = %s이다." % (a, b, result))

an = Service()
an.sum(1, 1)
# Out:
# 1 + 1 = 2이다.

# %% [markdown]
# ## p.19 객체 변수

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def setname(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service()
an.setname("박달도사")
an.sum(1, 1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %% [markdown]
# ## p.20 클래스 변수와 객체 변수

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

kim = Service()
park = Service()

kim.name = "김철수"
park.name = "박응용"

print(kim.name)
print(park.name)

kim.secret = "비밀은 없다"
print(park.secret)
print(kim.secret)
print(Service.secret)
# Out:
# 김철수
# 박응용
# 지구는 4006년에 멸망한다.
# 비밀은 없다
# 지구는 4006년에 멸망한다.

# %% [markdown]
# ## p.21 setname을 호출하지 않은 경우 발생하는 문제

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def setname(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

lee = Service()

# 아래 코드는 setname을 호출하지 않았기 때문에 AttributeError가 발생합니다.
# lee.sum(1, 1)

# %% [markdown]
# ## p.22 __init__

# %%
class Service:
    secret = "지구는 4006년에 멸망한다."

    def __init__(self, name):
        self.name = name

    def sum(self, a, b):
        result = a + b
        print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service("박달도사")
an.sum(1, 1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %% [markdown]
# ## p.23 클래스 구조 파악

# %%
class 클래스이름:
    클래스_변수_1 = None
    클래스_변수_2 = None

    def 메서드1(self, 인수1, 인수2):
        # 수행할 문장 1
        # 수행할 문장 2
        pass

    def 메서드2(self, 인수1, 인수2):
        # 수행할 문장 1
        # 수행할 문장 2
        pass

# %% [markdown]
# ## p.24 사칙연산 클래스: 껍데기 클래스

# %%
class FourCal:
    pass

a = FourCal()
print(type(a))
# Out:
# <class '__main__.FourCal'>

# %% [markdown]
# ## p.25 사칙연산 클래스: 데이터 세팅

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

a = FourCal()
a.setdata(4, 2)

print(a.first)
print(a.second)
# Out:
# 4
# 2

# %% [markdown]
# ## p.26 사칙연산 클래스: 더하기

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        result = self.first + self.second
        return result

a = FourCal()
a.setdata(4, 2)

print(a.sum())
# Out:
# 6

# %% [markdown]
# ## p.27 사칙연산 클래스: 전체

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def sum(self):
        result = self.first + self.second
        return result

    def mul(self):
        result = self.first * self.second
        return result

    def sub(self):
        result = self.first - self.second
        return result

    def div(self):
        result = self.first / self.second
        return result

a = FourCal()
b = FourCal()

a.setdata(4, 2)
b.setdata(3, 7)

print(a.sum())
print(a.mul())
print(a.sub())
print(a.div())
print(b.sub())
# Out:
# 6
# 8
# 2
# 2.0
# -4

# %% [markdown]
# ## p.30 간단한 주사위 게임: 순차적 프로그래밍

# %%
import random

player1_dice = []
player2_dice = []

for i in range(3):
    player1_dice.append(random.randint(1, 6))
    player2_dice.append(random.randint(1, 6))

print("Player 1 rolled " + str(player1_dice))
print("Player 2 rolled " + str(player2_dice))

if sum(player1_dice) == sum(player2_dice):
    print("Draw")
elif sum(player1_dice) > sum(player2_dice):
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Player 1 rolled [2, 6, 4]
# Player 2 rolled [5, 4, 5]
# Player 2 wins

# %% [markdown]
# ## p.31 간단한 주사위 게임: OOP

# %%
from random import randint

class Player:
    def __init__(self):
        self.dice = []

    def roll(self):
        self.dice = []  # clears current dice
        for i in range(3):
            self.dice.append(randint(1, 6))

    def get_dice(self):
        return self.dice

player1 = Player()
player2 = Player()

player1.roll()
player2.roll()

print("Player 1 rolled " + str(player1.get_dice()))
print("Player 2 rolled " + str(player2.get_dice()))

if sum(player1.get_dice()) == sum(player2.get_dice()):
    print("Draw")
elif sum(player1.get_dice()) > sum(player2.get_dice()):
    print("Player 1 wins!")
else:
    print("Player 2 wins!")
# Out:
# Player 1 rolled [5, 5, 6]
# Player 2 rolled [5, 3, 3]
# Player 1 wins!
