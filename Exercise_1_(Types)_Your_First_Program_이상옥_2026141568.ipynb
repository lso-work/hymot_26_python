# %% [markdown]
# <a href="https://colab.research.google.com/github/lso-work/hymot_26_python/blob/main/Exercise_1_(Types)_Your_First_Program_%EC%9D%B4%EC%83%81%EC%98%A5_2026141568.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h3 id="exercise">Exercise 1 (Types): Your First Program</h3>
# 숙제 제출시 반드시 "Exercise 1 (Types) : Your First Program"이라는 것과 함께, 자신의 이름과 학번을 꼭 기재하세요 (comment도 좋고, 아니면 파일이름에라도 좋고)

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("Hello, world!") # Print the traditional hello world
# Out:
# Hello, world!

# %% [markdown]
# <h3 id="exercise">Exercise 2 (Types):
#
#
# ---
#
# Get the object type</h3>

# %%
type(12.0)
# Out:
# float

# %% [markdown]
# <h3 id="exer_type">Exercise 3 (Types): Types</h3>
#
# > 인용구 추가

# %%
type(6/2)
# Out:
# float

# %%
type(6//2)
# Out:
# int

# %% [markdown]
# <h3 id="exer_exp">Exercise 4 (Types): Expression</h3>

# %%
160/60

160//60
# Out:
# 2

# %% [markdown]
# <h3 id="exer_exp_var">Exercise 5 (Types): Expression and Variables in Python</h3>

# %%
x = 3+2*2
x
# Out:
# 7

# %%
y = (3+2)*2
y
# Out:
# 10

# %%
z = x+y
z
# Out:
# 17
