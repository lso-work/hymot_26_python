# %% [markdown]
# <a href="https://colab.research.google.com/github/lso-work/hymot_26_python/blob/main/python_programming_9%EC%A3%BC_functions_%EC%9D%B4%EC%83%81%EC%98%A5_2026141568.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 프로그래밍 9주차 - 함수 고급

# %% [markdown]
# ## p.4 List Comprehension

# %%
# 방법 1: append()를 직접 사용
number_list = []
number_list.append(1)
number_list.append(2)
number_list.append(3)
number_list.append(4)
number_list.append(5)
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
# 방법 2: for 문 사용
number_list = []
for number in range(1, 6):
    number_list.append(number)
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
# 방법 3: list()와 range() 사용
number_list = list(range(1, 6))
number_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## p.5 List Comprehension

# %%
# 1부터 5까지의 정수 리스트 만들기 - list comprehension
number_list = [number for number in range(1, 6)]
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
# 함수 적용
number_list = [number - 1 for number in range(1, 6)]
number_list
# Out:
# [0, 1, 2, 3, 4]

# %%
# 조건 적용
a_list = [number for number in range(1, 6) if number % 2 == 1]
a_list
# Out:
# [1, 3, 5]

# %% [markdown]
# ## p.6 List Comprehension을 for 문으로 바꾸기

# %%
# List comprehension
a_list = [number for number in range(1, 6) if number % 2 == 1]
a_list
# Out:
# [1, 3, 5]

# %%
# 같은 내용을 for 문으로 작성
a_list = []
for number in range(1, 6):
    if number % 2 == 1:
        a_list.append(number)
a_list
# Out:
# [1, 3, 5]

# %% [markdown]
# ## p.7 List Comprehension 예제

# %%
sentence = ['I', 'Love', 'Python', 'Soooooo', 'MUCH!!!']

# 함수 적용
[word.lower() for word in sentence]
# Out:
# ['i', 'love', 'python', 'soooooo', 'much!!!']

# %%
# 조건 적용
[word for word in sentence if len(word) > 6]
# Out:
# ['Soooooo', 'MUCH!!!']

# %%
# 함수 적용하여 튜플로 저장
[(x, x ** 2, x ** 3) for x in range(10)]
# Out:
# [(0, 0, 0),
#  (1, 1, 1),
#  (2, 4, 8),
#  (3, 9, 27),
#  (4, 16, 64),
#  (5, 25, 125),
#  (6, 36, 216),
#  (7, 49, 343),
#  (8, 64, 512),
#  (9, 81, 729)]

# %% [markdown]
# ## p.8 List Comprehension - 두 개의 for

# %%
rows = range(1, 4)
cols = range(1, 3)

for row in rows:
    for col in cols:
        print(row, col)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2

# %%
rows = range(1, 4)
cols = range(1, 3)

cells = [(row, col) for row in rows for col in cols]
for cell in cells:
    print(cell)
# Out:
# (1, 1)
# (1, 2)
# (2, 1)
# (2, 2)
# (3, 1)
# (3, 2)

# %%
# 다음은 어떤 결과가 나올까?
[(i, j) for i in range(5) for j in range(i)]
# Out:
# [(1, 0),
#  (2, 0),
#  (2, 1),
#  (3, 0),
#  (3, 1),
#  (3, 2),
#  (4, 0),
#  (4, 1),
#  (4, 2),
#  (4, 3)]

# %% [markdown]
# ## p.9 Dictionary Comprehension

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in word}
letter_counts
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %% [markdown]
# ## p.10 Dictionary Comprehension - 중복 제거 방식

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in word}
letter_counts
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in set(word)}
letter_counts
# Out:
# {'r': 1, 't': 2, 'e': 2, 's': 1, 'l': 1}

# %% [markdown]
# ## p.11 Set Comprehension

# %%
a_set = {number for number in range(1, 6) if number % 3 == 1}
a_set
# Out:
# {1, 4}

# %% [markdown]
# ## p.12 Comprehension 추가 예시

# %%
# 딕셔너리의 key와 value를 뒤집는 예시
d = {'a': 1, 'b': 2, 'c': 3}
reversed_dict = {v: k for k, v in d.items()}
reversed_dict
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
# 회문(palindrome) 단어만 set으로 저장하는 예시
def is_palindrome(word):
    return word == word[::-1]

hamlet = ['level', 'Hamlet', 'madam', 'Python', 'radar', 'apple']
palindromes = {word for word in hamlet if is_palindrome(word.lower())}
palindromes
# Out:
# {'level', 'madam', 'radar'}

# %% [markdown]
# ## p.14 Functions - 기본 구조

# %%
# return 값을 갖는 함수의 기본 구조 예시
def function_name(param1, param2):
    value = param1 + param2
    return value

function_name(10, 20)
# Out:
# 30

# %% [markdown]
# ## p.15 Functions - 덧셈 함수 예제

# %%
def sum(a, b):
    return a + b

print(sum(1, 2))
print(sum(1.3, 3.1))
print(sum('love ', 'python'))
# Out:
# 3
# 4.4
# love python

# %% [markdown]
# ## p.16 iteration - zip()

# %%
days = ['Monday', 'Tuesday', 'Wednesday']
fruits = ['banana', 'orange', 'peach']
drinks = ['coffee', 'tea', 'beer']
desserts = ['tiramisu', 'ice cream', 'pie', 'pudding']

for day, fruit, drink, dessert in zip(days, fruits, drinks, desserts):
    print(day, ': drink', drink, '- eat', fruit, '- enjoy', dessert)
# Out:
# Monday : drink coffee - eat banana - enjoy tiramisu
# Tuesday : drink tea - eat orange - enjoy ice cream
# Wednesday : drink beer - eat peach - enjoy pie

# %% [markdown]
# ## p.17 iteration - zip()으로 영어-프랑스어 사전 만들기

# %%
english = 'Monday', 'Tuesday', 'Wednesday'
french = 'Lundi', 'Mardi', 'Mercredi'

list(zip(english, french))
# Out:
# [('Monday', 'Lundi'), ('Tuesday', 'Mardi'), ('Wednesday', 'Mercredi')]

# %%
dict(zip(english, french))
# Out:
# {'Monday': 'Lundi', 'Tuesday': 'Mardi', 'Wednesday': 'Mercredi'}

# %% [markdown]
# ## p.18 함수 위치 인자

# %%
# wine, entree, dessert를 받아서 딕셔너리로 만들어 반환하는 함수
def menu(wine, entree, dessert):
    return {'wine': wine, 'entree': entree, 'dessert': dessert}

menu('chardonnay', 'chicken', 'cake')
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'cake'}

# %% [markdown]
# ## p.19 함수 키워드 인자

# %%
# wine, entree, dessert를 받아서 딕셔너리로 만들어 반환하는 함수
def menu(wine, entree, dessert):
    return {'wine': wine, 'entree': entree, 'dessert': dessert}

menu(entree='beef', dessert='bagel', wine='bordeaux')
# Out:
# {'wine': 'bordeaux', 'entree': 'beef', 'dessert': 'bagel'}

# %%
# 위치 인자와 키워드 인자를 섞어서 사용 가능
# 단, 위치 인자가 먼저 나와야 함
menu('frontenac', dessert='flan', entree='fish')
# Out:
# {'wine': 'frontenac', 'entree': 'fish', 'dessert': 'flan'}

# %% [markdown]
# ## p.20 기본 매개변수 값 정하기

# %%
# dessert의 기본값을 정해줌
def menu(wine, entree, dessert='pudding'):
    return {'wine': wine, 'entree': entree, 'dessert': dessert}

menu('chardonnay', 'chicken')
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}

# %%
# dessert 값을 입력한 경우
menu('dunkelfelder', 'duck', 'doughnut')
# Out:
# {'wine': 'dunkelfelder', 'entree': 'duck', 'dessert': 'doughnut'}

# %% [markdown]
# ## p.21 가능한 경우

# %%
def menu(price, wine='chardonnay', entree='chicken', dessert='pudding'):
    return {'price': price, 'wine': wine, 'entree': entree, 'dessert': dessert}

print(menu(100))                              # 1 위치 인자
print(menu(price=100))                        # 1 키워드 인자
print(menu(price=120, entree='beef'))         # 2 키워드 인자
print(menu(dessert='bagel', price=110))       # 2 키워드 인자
print(menu('eighty', 'saint-pierre', 'fish')) # 3 위치 인자
print(menu('hundred', wine='saint-pierre'))   # 1 위치 인자, 1 키워드 인자
# Out:
# {'price': 100, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}
# {'price': 100, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}
# {'price': 120, 'wine': 'chardonnay', 'entree': 'beef', 'dessert': 'pudding'}
# {'price': 110, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'bagel'}
# {'price': 'eighty', 'wine': 'saint-pierre', 'entree': 'fish', 'dessert': 'pudding'}
# {'price': 'hundred', 'wine': 'saint-pierre', 'entree': 'chicken', 'dessert': 'pudding'}

# %% [markdown]
# ## p.22 불가능한 경우

# %%
def menu(price, wine='chardonnay', entree='chicken', dessert='pudding'):
    return {'price': price, 'wine': wine, 'entree': entree, 'dessert': dessert}


# menu()                              # price에 인자가 할당되지 않음
# menu(price=100, 'saint-pierre')     # 키워드 인자 할당 후 위치 인자 사용
# menu(100, price=120)                # 같은 변수 price에 두 번 할당
# menu(main='cream pasta')            # 정의되지 않은 매개변수 main 사용

# %% [markdown]
# ## p.23 docstring

# %%
def echo(anything):
    'echo returns its input argument'
    return anything

echo('hello')
# Out:
# 'hello'

# %%
def print_if_true(thing, check):
    """
    Prints the first argument if a second argument is true.
    The operation is:
    1. Check whether the *second* argument is true.
    2. If it is, print the *first* argument.
    """
    if check:
        print(thing)

print_if_true('Python', True)
print_if_true('This will not be printed', False)
# Out:
# Python

# %%
print_if_true('hahaha', False)

# %%
print_if_true('hahaha', 1!=3)
# Out:
# hahaha

# %% [markdown]
# ## p.24 docstring - help()와 __doc__

# %%
help(echo)
# Out:
# Help on function echo in module __main__:
#
# echo(anything)
#     echo returns its input argument

# %%
print(echo.__doc__)
# Out:
# echo returns its input argument
